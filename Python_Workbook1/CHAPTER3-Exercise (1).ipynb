# %% [markdown]
# Exercise 1

# %%
#in the code below, which will never print regardless of the value for x? Edit the code to correct the error.
x = 21

if x > 50 :
    print('Above 50')
elif x > 20 :
    print('Above 20')
elif x > 10 :
    print('Above 10')
elif x > 0 :
    print('Above 0')
else :
    print('Something else')
    # need initialize the value of x
# Out:
# Above 20

# %% [markdown]
# Exercise 2

# %%
#Write your salary computation to give an employee 1.5 times the hourly rate for hours worked above 40 hours. Example:
    hours = int (input("Enter hours:"))
    rate = float(input("Enter Rate:"))

if hours > 40:
    ratePay = 40 * rate
    overtimePay = (hours - 40)* (rate * 1.5)
    totalp = ratePay + overtimePay
else:
    totalp = hours * rate
# Out:
#   File "<ipython-input-2-843e14a1156c>", line 2
#     hours = int (input("Enter hours:"))
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Challenge

# %%
#Write a program to prompt for a score between 0 and 100 and print a grade using the following table
grade = int(input("Enter Grade: "))

if(grade >= 97):
  print("1.0")
elif(grade >= 93):
  print("1.25")
elif(grade >= 89):
  print("1.5")
elif(grade >= 85):
  print("1.75")
elif(grade >= 81):
  print("2.0")
elif(grade >= 77):
  print("2.25")
elif(grade >= 74):
  print("2.5")
elif(grade >= 0):
  print("3.0")
# Out:
#   File "<tokenize>", line 32
#     elif(grade >= 89):
#     ^
# IndentationError: unindent does not match any outer indentation level
