# %% [markdown]
# EXERCISE 1

# %%
print('Hello world!')
# Error: Print('Hello world!')- it must be lowcase
#The functions in python are also case sensitive
# Out:
# Hello world!

# %%
print('Hello world!')
#Error:print'Hello world!')-Missing open bracket

# %%
print('Hello world!')
#Error: print('Hello world!)-Missing single quotation mark

# %%
print('Hello world!')
#Error: print('Hello world!'')-Extra single quotation mark
# Out:
# Hello world!

# %% [markdown]
# EXERCISE 2

# %%
x = 43
x = x + 1
print(x)
#No error
# Out:
# 44

# %%
x = 43
x = x + 1
print(x)
#Error:x = X + 1 The initialize variable name is in uppercase change to lowercase
# Out:
# 44
