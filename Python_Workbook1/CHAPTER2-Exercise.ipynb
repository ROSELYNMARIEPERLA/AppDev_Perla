# %% [markdown]
#   EXERCISE 1:
#   Write a program that uses input to prompt a user for their name and then welcomes them.

# %%
name = input('Enter you name?')
print('hello', name)
# Out:
# Enter you name?perla
# hello perla

# %% [markdown]
# EXERCISE 2: Write a program to prompt the user for hours and rate per hour to compute gross pay.

# %%
hour = int (input("Enter hours:"))
rate = float (input("Enter rate:"))

pay = hour * rate
print(pay)
# Out:
# Enter hours:35
# Enter rate:2.75
# 96.25

# %% [markdown]
# EXERCISE 3: Assume that we execute the following assignment statements:

# %%
#Assume that we execute the following assignment statements:
#width = 17
#height = 12.0

width = 17
height = 12.0

width//2
width/2.0
height/3
1 + 2 * 5
# Out:
# 11

# %% [markdown]
# EXERCISE 4:For each of the following expressions, write the value of the expression and the type (of the value of the expression).

# %%
#Write a program that uses input to prompt a user for a number and then outputs the square of the number
num = int(input("Enter a number"))
square = num**2
print("the suquare of",num,"is",square)
# Out:
# Enter a number3
# the suquare of 3 is 9

# %% [markdown]
# CHALLENGE

# %%
#Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.
celsius = float(input("Enter the temperature in Celsuis"))
fahrenheit = (celsius * 9/5)+32
print("The temperature in Fahrenheit is:",fahrenheit)
# Out:
# Enter the temperature in Celsuis30
# The temperature in Fahrenheit is: 86.0
