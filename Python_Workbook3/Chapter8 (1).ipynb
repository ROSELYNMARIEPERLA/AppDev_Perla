# %%
 #CHAPTER 8

# %% [markdown]
# Exercise 1:

# %% [markdown]
# Create ab enpty list then add the following numbers using append: 4, 6 9.

# %%
empty_List = []
empty_List.append(4)
empty_List.append(6)
empty_List.append(9)
print(empty_List)
# Out:
# [4, 6, 9]

# %% [markdown]
# Exercise 2:

# %% [markdown]
# Using the range function, create a list containing the numbers from 0 to 10.

# %%
num_list= list(range(11))
print(tnum_lis)

# %% [markdown]
# Exercise 3:

# %% [markdown]
# Create a list containing the valid grade values, then using enumerate in a for loop, print out all indices and items in the list.

# %% [markdown]
# It should print out:

# %%
#0   1.0
#1   1.25
#2   1.5
#3   1.75
#4   2.0
#5   2.25
#6   2.5
#7   3.0

# %%
grade = [1.0, 1.25, 1.5, 1.75, 2.0, 2.25, 3.0]
for index, grade in enumerate(grade):
  print(index, grade)

# %% [markdown]
# Exercise 4:

# %% [markdown]
# Using index slicing, prinnt out the list of grades higher than 2.0

# %%
#Dosgrade = grade.index(2.0) + 1
#print(grade[Dosgrade:])
print(grade[5:])

# %% [markdown]
# Exercise 5:

# %% [markdown]
# Using Index Slicing, print out the list of grades better than 2.0.

# %%
#Dosgrade = grade.index(2.0)
#print(grade[Dosgrade:])
print(grade[:4])

# %% [markdown]
# Exercise 6:

# %% [markdown]
# Using Index Slicing, print out the grades 2.0,2.25,2.5.

# %%
#limitgrade = grade.index(2.5) + 1
#print(grade[Dosgrade:limitgrade])
print(grade[4:7])

# %% [markdown]
# CHALLENGE!

# %% [markdown]
# Modify the code in the subheading Parsing Lines to display all the time stamps of the emails in mboxt-short.txt

# %%
fhand = open('mbox.txt')
my_list = []
for line in fhand:
    line = line.rstrip()
    if not line.startswith('From'):
        continue
    words = line.split()
    if my_list == []:
        my_list.append(words[1])
    elif words[1] not in my_list:
         my_list.append(words[1])
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-179efb213eae> in <cell line: 1>()
# ----> 1 fhand = open('mbox.txt')
#       2 my_list = []
#       3 for line in fhand:
#       4     line = line.rstrip()
#       5     if not line.startswith('From'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mbox.txt'
